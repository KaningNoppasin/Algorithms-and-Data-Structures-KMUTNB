# %%
class Empty(Exception):
    """Error attempting to access an element from an empty container."""
    pass

class ArrayStack:
    """LIFO Stack implementation using a Python list as underlying storage."""

    def __init__(self):
        """Create an empty stack."""
        self._data = []
        self._size = 0

    def __len__(self):
        """Return the number of elements in the stack."""
        return self._size

    def is_empty(self):
        """Return True if the stack is empty."""
        return self._size == 0

    def push(self, e):
        """Add element e to the top of the stack."""
        self._data.append(e)
        self._size += 1

    def top(self):
        """Return (but do not remove) the element at the top of the stack.

        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty("Stack is Empty")
        return self._data[-1]

    def pop(self):
        """Remove and return the element from the top of the stack (i.e., LIFO).

        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty("Stack is Empty")
        self._size -= 1
        return self._data.pop()

def PrefixtoInfix(prefix_exp):
    '''Convert prefix to infix expression
    Prefix: +AB
    Infix:  (A+B)

    Prefix: +A*BC
    Infix:  (A+(B*C))
    '''
    operand = [chr(c) for c in range(ord('A'),ord('Z'))] + [str(i) for i in range(0,10)]
    operator = "+-*/^"
    expressionStack = ArrayStack()

    for i in range(len(prefix_exp) - 1,-1,-1):
        item = prefix_exp[i]
        # a-z
        if item in operand:
            expressionStack.push(item)

        # +-*/^
        elif item in operator:
            first_data = expressionStack.pop()
            second_data = expressionStack.pop()
            expressionStack.push(f"({first_data}{item}{second_data})")
            # print(expressionStack._data,item)

    answer = expressionStack.pop()
    return answer

# exp = "+AB"
# print('Prefix:',exp)
# print('Infix: ',PrefixtoInfix(exp))
# exp = "+A*BC"
# print('Prefix:',exp)
# print('Infix: ',PrefixtoInfix(exp))
# exp = "*+ABC"
# print('Prefix:',exp)
# print('Infix: ',PrefixtoInfix(exp))

exp = "*4-5+72"
print('Prefix:',exp)
print('Infix: ',PrefixtoInfix(exp))
exp = "/*+3427"
print('Prefix:',exp)
print('Infix: ',PrefixtoInfix(exp))
# Out:
# Prefix: *4-5+72
# ['(7+2)'] +
# ['(5-(7+2))'] -
# ['(4*(5-(7+2)))'] *
# Infix:  (4*(5-(7+2)))
# Prefix: /*+3427
# ['7', '2', '(3+4)'] +
# ['7', '((3+4)*2)'] *
# ['(((3+4)*2)/7)'] /
# Infix:  (((3+4)*2)/7)

# %%
class Empty(Exception):
    """Error attempting to access an element from an empty container."""
    pass

class ArrayStack:
    """LIFO Stack implementation using a Python list as underlying storage."""

    def __init__(self):
        """Create an empty stack."""
        self._data = []
        self._size = 0

    def __len__(self):
        """Return the number of elements in the stack."""
        return self._size

    def is_empty(self):
        """Return True if the stack is empty."""
        return self._size == 0

    def push(self, e):
        """Add element e to the top of the stack."""
        self._data.append(e)
        self._size += 1

    def top(self):
        """Return (but do not remove) the element at the top of the stack.

        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty("Stack is Empty")
        return self._data[-1]

    def pop(self):
        """Remove and return the element from the top of the stack (i.e., LIFO).

        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty("Stack is Empty")
        self._size -= 1
        return self._data.pop()

def evaluatePostfix(postfix_exp):
    '''Evaluate postfix expression'''
    operand = [chr(c) for c in range(ord('A'),ord('Z'))] + [str(i) for i in range(0,10)]
    operator = "+-*/^"
    expressionStack = ArrayStack()

    for item in postfix_exp:
        if item in operand:
            expressionStack.push(item)
        elif item in operator:
            first_data = expressionStack.pop()
            second_data = expressionStack.pop()
            expressionStack.push(f"({second_data}{item}{first_data})")
    return float(eval(expressionStack.pop()))
    # return (expressionStack.pop())
exp = "4572+-*"
print(exp,'=',evaluatePostfix(exp))
exp = "34+2*7/"
print(exp,'=',evaluatePostfix(exp))
# Out:
# 4572+-* = (4*(5-(7+2)))
# 34+2*7/ = (((3+4)*2)/7)

# %%
# ผิด ไม่ได้เรียงลำดับความสำคัญของ operator
class Empty(Exception):
    """Error attempting to access an element from an empty container."""
    pass

class ArrayStack:
    """LIFO Stack implementation using a Python list as underlying storage."""

    def __init__(self):
        """Create an empty stack."""
        self._data = []
        self._size = 0

    def __len__(self):
        """Return the number of elements in the stack."""
        return self._size

    def is_empty(self):
        """Return True if the stack is empty."""
        return self._size == 0

    def push(self, e):
        """Add element e to the top of the stack."""
        self._data.append(e)
        self._size += 1

    def top(self):
        """Return (but do not remove) the element at the top of the stack.

        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty("Stack is Empty")
        return self._data[-1]

    def pop(self):
        """Remove and return the element from the top of the stack (i.e., LIFO).

        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty("Stack is Empty")
        self._size -= 1
        return self._data.pop()

def InfixtoPostfix(inxfix_exp):
    '''Convert infix to postfix expression
    Infix:   A+B
    Postfix: AB+

    Infix:   A+B*C
    Postfix: ABC*+

    Infix:   (A+B)*C
    Postfix: AB+C*
    '''
    operand = [chr(c) for c in range(ord('A'),ord('Z'))] + [str(i) for i in range(0,10)]
    operator = "+-*/^"
    operandStack = ArrayStack()
    operatorStack = ArrayStack()
    answer = ""
    for item in inxfix_exp:
        if item in operand:
            operandStack.push(item)
        elif item in operator:
            operatorStack.push(item)
        elif item == "(":
            operandStack.push(item)
        elif item == ")":
            if "(" not in operandStack._data:
                raise Exception("Expression Error")
            first_data = operandStack.pop()
            second_data = operandStack.pop()
            operandStack.pop() # => (
            operandStack.push(f"{second_data}{first_data}{operatorStack.pop()}")
    else:
        while not operandStack.is_empty():
            answer = operandStack.pop() + answer
        while not operatorStack.is_empty():
            answer += operatorStack.pop()

    return answer

# exp = "A+B"
# print('Infix:  ',exp)
# print('Postfix:',InfixtoPostfix(exp))
# exp = "A+B*C"
# print('Infix:  ',exp)
# print('Postfix:',InfixtoPostfix(exp))
exp = "(A+B)*C"
print('Infix:  ',exp)
print('Postfix:',InfixtoPostfix(exp))
# Out:
# Infix:   (A+B)*C
# Postfix: AB+C*

# %%
class Empty(Exception):
    """Error attempting to access an element from an empty container."""
    pass

class ArrayStack:
    """LIFO Stack implementation using a Python list as underlying storage."""

    def __init__(self):
        """Create an empty stack."""
        self._data = []
        self._size = 0

    def __len__(self):
        """Return the number of elements in the stack."""
        return self._size

    def is_empty(self):
        """Return True if the stack is empty."""
        return self._size == 0

    def push(self, e):
        """Add element e to the top of the stack."""
        self._data.append(e)
        self._size += 1

    def top(self):
        """Return (but do not remove) the element at the top of the stack.

        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty("Stack is Empty")
        return self._data[-1]

    def pop(self):
        """Remove and return the element from the top of the stack (i.e., LIFO).

        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty("Stack is Empty")
        self._size -= 1
        return self._data.pop()

def InfixtoPostfix(inxfix_exp):
    '''Convert infix to postfix expression
    Infix:   A+B
    Postfix: AB+

    Infix:   A+B*C
    Postfix: ABC*+

    Infix:   (A+B)*C
    Postfix: AB+C*
    '''
    operand = [chr(c) for c in range(ord('A'),ord('Z'))] + [str(i) for i in range(0,10)]
    operator = "+-*/^"
    operatorStack = ArrayStack()
    answer = ""
    for item in inxfix_exp:
        # print(answer)
        if item in operand:
            answer += item
        elif item in operator:
            if item in "^":
                # answer += item # => ^
                while not operatorStack.is_empty():
                    answer += operatorStack.pop()
                operatorStack.push(item)
            elif item in "*/":
                # answer += item # => * , /
                while not operatorStack.is_empty():
                    answer += operatorStack.pop()
                operatorStack.push(item)
            elif item in "+-":
                operatorStack.push(item)
    else:
        while not operatorStack.is_empty():
                    answer += operatorStack.pop()
    return answer

exp = "A+B"
print('Infix:  ',exp)
print('Postfix:',InfixtoPostfix(exp))
exp = "A+B*C"
print('Infix:  ',exp)
print('Postfix:',InfixtoPostfix(exp))
exp = "(A+B)*C"
print('Infix:  ',exp)
print('Postfix:',InfixtoPostfix(exp))
# Out:
# Infix:   A+B
# Postfix: AB+
# Infix:   A+B*C
# Postfix: AB+C*
# Infix:   (A+B)*C
# Postfix: AB+C*

# %%
string = "123456789"

print(string[::-1])
# Out:
# 987654321
